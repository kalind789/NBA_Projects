# %%
# !pip install --quiet beautifulsoup4 html5lib

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
team = "ATL"
# url = f"https://www.basketball-reference.com/teams/{team}/2026.html"
url = "https://www.basketball-reference.com/teams/ATL/2026.html#roster"

# response = requests.get(url)
# html_content = response.text

roster_df = pd.read_html(url)

# %%
roster_df = roster_df[0]

# %%
roster_df
# Out:
#     No.                    Player  Pos    Ht     Wt          Birth Date  \
# 0   NaN           Eli Ndiaye (TW)    C   6-8    NaN       June 26, 2004
# 1   NaN             Caleb Houstan  G-F   6-8  205.0     January 9, 2003
# 2   NaN              N'Faly Dante    C  6-11  230.0    October 19, 2001
# 3   NaN       Keaton Wallace (TW)    G   6-3  195.0   February 26, 1999
# 4   NaN         Jacob Toppin (TW)    F   6-9  205.0         May 8, 2000
# 5   NaN           Nikola Djurisic    G   6-7  209.0   February 23, 2004
# 6   NaN              Luke Kennard    G   6-5  206.0       June 24, 1996
# 7   NaN  Nickeil Alexander-Walker    G   6-5  205.0   September 2, 1998
# 8   NaN                Asa Newell    F  6-11    NaN     October 5, 2005
# 9   NaN                Trae Young    G   6-1  164.0  September 19, 1998
# 10  NaN             Jalen Johnson    F   6-9  220.0   December 18, 2001
# 11  NaN                Vit Krejci    G   6-8  195.0       June 19, 2000
# 12  NaN        Zaccharie Risacher    F   6-8  200.0       April 8, 2005
# 13  NaN            Onyeka Okongwu    F   6-8  235.0   December 11, 2000
# 14  NaN        Kristaps Porziņģis  F-C   7-2  240.0      August 2, 1995
# 15  NaN               Kobe Bufkin    G   6-4  195.0  September 21, 2003
# 16  NaN            Mouhamed Gueye    F  6-11  210.0    November 9, 2002
# 17  NaN             Dyson Daniels    G   6-8  199.0      March 17, 2003
#
#     Birth Exp                 College
# 0   sn SN   R                     NaN
# 1   ca CA   3                Michigan
# 2   ml ML   1                  Oregon
# 3   us US   1       Texas-San Antonio
# 4   us US   2  Rhode Island, Kentucky
# 5   be BE   R                     NaN
# 6   us US   8                    Duke
# 7   ca CA   6           Virginia Tech
# 8   us US   R                 Georgia
# 9   us US   7                Oklahoma
# 10  us US   4                    Duke
# 11  cz CZ   4                     NaN
# 12  es ES   1                     NaN
# 13  us US   5                     USC
# 14  lv LV   9                     NaN
# 15  us US   2                Michigan
# 16  sn SN   2        Washington State
# 17  au AU   3                     NaN

# %%
roster_df = roster_df.drop(columns=["No."])

# %%
roster_df
# Out:
#                       Player  Pos    Ht     Wt          Birth Date  Birth Exp  \
# 0            Eli Ndiaye (TW)    C   6-8    NaN       June 26, 2004  sn SN   R
# 1              Caleb Houstan  G-F   6-8  205.0     January 9, 2003  ca CA   3
# 2               N'Faly Dante    C  6-11  230.0    October 19, 2001  ml ML   1
# 3        Keaton Wallace (TW)    G   6-3  195.0   February 26, 1999  us US   1
# 4          Jacob Toppin (TW)    F   6-9  205.0         May 8, 2000  us US   2
# 5            Nikola Djurisic    G   6-7  209.0   February 23, 2004  be BE   R
# 6               Luke Kennard    G   6-5  206.0       June 24, 1996  us US   8
# 7   Nickeil Alexander-Walker    G   6-5  205.0   September 2, 1998  ca CA   6
# 8                 Asa Newell    F  6-11    NaN     October 5, 2005  us US   R
# 9                 Trae Young    G   6-1  164.0  September 19, 1998  us US   7
# 10             Jalen Johnson    F   6-9  220.0   December 18, 2001  us US   4
# 11                Vit Krejci    G   6-8  195.0       June 19, 2000  cz CZ   4
# 12        Zaccharie Risacher    F   6-8  200.0       April 8, 2005  es ES   1
# 13            Onyeka Okongwu    F   6-8  235.0   December 11, 2000  us US   5
# 14        Kristaps Porziņģis  F-C   7-2  240.0      August 2, 1995  lv LV   9
# 15               Kobe Bufkin    G   6-4  195.0  September 21, 2003  us US   2
# 16            Mouhamed Gueye    F  6-11  210.0    November 9, 2002  sn SN   2
# 17             Dyson Daniels    G   6-8  199.0      March 17, 2003  au AU   3
#
#                    College
# 0                      NaN
# 1                 Michigan
# 2                   Oregon
# 3        Texas-San Antonio
# 4   Rhode Island, Kentucky
# 5                      NaN
# 6                     Duke
# 7            Virginia Tech
# 8                  Georgia
# 9                 Oklahoma
# 10                    Duke
# 11                     NaN
# 12                     NaN
# 13                     USC
# 14                     NaN
# 15                Michigan
# 16        Washington State
# 17                     NaN

# %%
roster_df["Birth"] = roster_df["Birth"].apply(lambda x: x.split()[1])

# %%
roster_df
# Out:
#                       Player  Pos    Ht     Wt          Birth Date Birth Exp  \
# 0            Eli Ndiaye (TW)    C   6-8    NaN       June 26, 2004    SN   R
# 1              Caleb Houstan  G-F   6-8  205.0     January 9, 2003    CA   3
# 2               N'Faly Dante    C  6-11  230.0    October 19, 2001    ML   1
# 3        Keaton Wallace (TW)    G   6-3  195.0   February 26, 1999    US   1
# 4          Jacob Toppin (TW)    F   6-9  205.0         May 8, 2000    US   2
# 5            Nikola Djurisic    G   6-7  209.0   February 23, 2004    BE   R
# 6               Luke Kennard    G   6-5  206.0       June 24, 1996    US   8
# 7   Nickeil Alexander-Walker    G   6-5  205.0   September 2, 1998    CA   6
# 8                 Asa Newell    F  6-11    NaN     October 5, 2005    US   R
# 9                 Trae Young    G   6-1  164.0  September 19, 1998    US   7
# 10             Jalen Johnson    F   6-9  220.0   December 18, 2001    US   4
# 11                Vit Krejci    G   6-8  195.0       June 19, 2000    CZ   4
# 12        Zaccharie Risacher    F   6-8  200.0       April 8, 2005    ES   1
# 13            Onyeka Okongwu    F   6-8  235.0   December 11, 2000    US   5
# 14        Kristaps Porziņģis  F-C   7-2  240.0      August 2, 1995    LV   9
# 15               Kobe Bufkin    G   6-4  195.0  September 21, 2003    US   2
# 16            Mouhamed Gueye    F  6-11  210.0    November 9, 2002    SN   2
# 17             Dyson Daniels    G   6-8  199.0      March 17, 2003    AU   3
#
#                    College
# 0                      NaN
# 1                 Michigan
# 2                   Oregon
# 3        Texas-San Antonio
# 4   Rhode Island, Kentucky
# 5                      NaN
# 6                     Duke
# 7            Virginia Tech
# 8                  Georgia
# 9                 Oklahoma
# 10                    Duke
# 11                     NaN
# 12                     NaN
# 13                     USC
# 14                     NaN
# 15                Michigan
# 16        Washington State
# 17                     NaN

# %%
roster_df
# Out:
#                       Player  Pos    Ht     Wt          Birth Date Birth Exp  \
# 0            Eli Ndiaye (TW)    C   6-8    NaN       June 26, 2004    SN   R
# 1              Caleb Houstan  G-F   6-8  205.0     January 9, 2003    CA   3
# 2               N'Faly Dante    C  6-11  230.0    October 19, 2001    ML   1
# 3        Keaton Wallace (TW)    G   6-3  195.0   February 26, 1999    US   1
# 4          Jacob Toppin (TW)    F   6-9  205.0         May 8, 2000    US   2
# 5            Nikola Djurisic    G   6-7  209.0   February 23, 2004    BE   R
# 6               Luke Kennard    G   6-5  206.0       June 24, 1996    US   8
# 7   Nickeil Alexander-Walker    G   6-5  205.0   September 2, 1998    CA   6
# 8                 Asa Newell    F  6-11    NaN     October 5, 2005    US   R
# 9                 Trae Young    G   6-1  164.0  September 19, 1998    US   7
# 10             Jalen Johnson    F   6-9  220.0   December 18, 2001    US   4
# 11                Vit Krejci    G   6-8  195.0       June 19, 2000    CZ   4
# 12        Zaccharie Risacher    F   6-8  200.0       April 8, 2005    ES   1
# 13            Onyeka Okongwu    F   6-8  235.0   December 11, 2000    US   5
# 14        Kristaps Porziņģis  F-C   7-2  240.0      August 2, 1995    LV   9
# 15               Kobe Bufkin    G   6-4  195.0  September 21, 2003    US   2
# 16            Mouhamed Gueye    F  6-11  210.0    November 9, 2002    SN   2
# 17             Dyson Daniels    G   6-8  199.0      March 17, 2003    AU   3
#
#                    College
# 0            International
# 1                 Michigan
# 2                   Oregon
# 3        Texas-San Antonio
# 4   Rhode Island, Kentucky
# 5            International
# 6                     Duke
# 7            Virginia Tech
# 8                  Georgia
# 9                 Oklahoma
# 10                    Duke
# 11           International
# 12           International
# 13                     USC
# 14           International
# 15                Michigan
# 16        Washington State
# 17           International

# %%
salary_url = f"https://www.basketball-reference.com/contracts/{team}.html#contracts"
salary_df = pd.read_html(salary_url)[0]
salary_df
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0        Salary                \
#                       Player                Age       2025-26       2026-27
# 0                 Trae Young               26.0   $45,999,660   $48,967,380
# 1         Kristaps Porziņģis               30.0   $30,731,707           NaN
# 2              Jalen Johnson               23.0   $30,000,000   $30,000,000
# 3             Onyeka Okongwu               24.0   $15,000,000   $16,120,000
# 4         Zaccharie Risacher               20.0   $13,197,720   $13,826,040
# 5              Dyson Daniels               22.0    $7,707,709           NaN
# 6                Kobe Bufkin               21.0    $4,503,720    $6,904,203
# 7                 Asa Newell               19.0    $3,237,480    $3,399,480
# 8                 Vit Krejci               25.0    $2,349,578    $2,667,944
# 9             Mouhamed Gueye               22.0    $2,221,677    $2,406,205
# 10              Luke Kennard               29.0           NaN           NaN
# 11                Eli Ndiaye               21.0           NaN           NaN
# 12              N'Faly Dante               23.0           NaN           NaN
# 13             Caleb Houstan               22.0           NaN           NaN
# 14           Nikola Djurisic               21.0           NaN           NaN
# 15              Jacob Toppin               25.0           NaN           NaN
# 16            Keaton Wallace               26.0           NaN           NaN
# 17  Nickeil Alexander-Walker               27.0           NaN           NaN
# 18                       NaN                NaN           NaN           NaN
# 19               David Roddy               24.0           NaN           NaN
# 20               Team Totals                NaN  $154,949,251  $124,291,252
#
#                                                   Unnamed: 8_level_0  \
#         2027-28      2028-29      2029-30 2030-31         Guaranteed
# 0           NaN          NaN          NaN     NaN        $45,999,660
# 1           NaN          NaN          NaN     NaN        $30,731,707
# 2   $30,000,000  $30,000,000  $30,000,000     NaN       $150,000,000
# 3   $16,880,000          NaN          NaN     NaN        $48,000,000
# 4   $17,434,637          NaN          NaN     NaN        $13,197,720
# 5           NaN          NaN          NaN     NaN         $7,707,709
# 6           NaN          NaN          NaN     NaN         $4,503,720
# 7    $3,560,880   $6,042,814          NaN     NaN         $6,636,960
# 8    $3,005,085          NaN          NaN     NaN                NaN
# 9           NaN          NaN          NaN     NaN                NaN
# 10          NaN          NaN          NaN     NaN                NaN
# 11          NaN          NaN          NaN     NaN                NaN
# 12          NaN          NaN          NaN     NaN                NaN
# 13          NaN          NaN          NaN     NaN                NaN
# 14          NaN          NaN          NaN     NaN                NaN
# 15          NaN          NaN          NaN     NaN                NaN
# 16          NaN          NaN          NaN     NaN                NaN
# 17          NaN          NaN          NaN     NaN                NaN
# 18          NaN          NaN          NaN     NaN                NaN
# 19          NaN          NaN          NaN     NaN                NaN
# 20  $70,880,602  $36,042,814  $30,000,000     NaN       $306,777,476
#
#    Unnamed: 9_level_0
#    Unnamed: 9_level_1
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN

# %%
salary_df = salary_df.droplevel(0, axis=1)

# %%
salary_df
# Out:
#                       Player   Age       2025-26       2026-27      2027-28  \
# 0                 Trae Young  26.0   $45,999,660   $48,967,380          NaN
# 1         Kristaps Porziņģis  30.0   $30,731,707           NaN          NaN
# 2              Jalen Johnson  23.0   $30,000,000   $30,000,000  $30,000,000
# 3             Onyeka Okongwu  24.0   $15,000,000   $16,120,000  $16,880,000
# 4         Zaccharie Risacher  20.0   $13,197,720   $13,826,040  $17,434,637
# 5              Dyson Daniels  22.0    $7,707,709           NaN          NaN
# 6                Kobe Bufkin  21.0    $4,503,720    $6,904,203          NaN
# 7                 Asa Newell  19.0    $3,237,480    $3,399,480   $3,560,880
# 8                 Vit Krejci  25.0    $2,349,578    $2,667,944   $3,005,085
# 9             Mouhamed Gueye  22.0    $2,221,677    $2,406,205          NaN
# 10              Luke Kennard  29.0           NaN           NaN          NaN
# 11                Eli Ndiaye  21.0           NaN           NaN          NaN
# 12              N'Faly Dante  23.0           NaN           NaN          NaN
# 13             Caleb Houstan  22.0           NaN           NaN          NaN
# 14           Nikola Djurisic  21.0           NaN           NaN          NaN
# 15              Jacob Toppin  25.0           NaN           NaN          NaN
# 16            Keaton Wallace  26.0           NaN           NaN          NaN
# 17  Nickeil Alexander-Walker  27.0           NaN           NaN          NaN
# 18                       NaN   NaN           NaN           NaN          NaN
# 19               David Roddy  24.0           NaN           NaN          NaN
# 20               Team Totals   NaN  $154,949,251  $124,291,252  $70,880,602
#
#         2028-29      2029-30  2030-31    Guaranteed  Unnamed: 9_level_1
# 0           NaN          NaN      NaN   $45,999,660                 NaN
# 1           NaN          NaN      NaN   $30,731,707                 NaN
# 2   $30,000,000  $30,000,000      NaN  $150,000,000                 NaN
# 3           NaN          NaN      NaN   $48,000,000                 NaN
# 4           NaN          NaN      NaN   $13,197,720                 NaN
# 5           NaN          NaN      NaN    $7,707,709                 NaN
# 6           NaN          NaN      NaN    $4,503,720                 NaN
# 7    $6,042,814          NaN      NaN    $6,636,960                 NaN
# 8           NaN          NaN      NaN           NaN                 NaN
# 9           NaN          NaN      NaN           NaN                 NaN
# 10          NaN          NaN      NaN           NaN                 NaN
# 11          NaN          NaN      NaN           NaN                 NaN
# 12          NaN          NaN      NaN           NaN                 NaN
# 13          NaN          NaN      NaN           NaN                 NaN
# 14          NaN          NaN      NaN           NaN                 NaN
# 15          NaN          NaN      NaN           NaN                 NaN
# 16          NaN          NaN      NaN           NaN                 NaN
# 17          NaN          NaN      NaN           NaN                 NaN
# 18          NaN          NaN      NaN           NaN                 NaN
# 19          NaN          NaN      NaN           NaN                 NaN
# 20  $36,042,814  $30,000,000      NaN  $306,777,476                 NaN

# %%
salary_df = salary_df[["Player", "Age", "2025-26"]]

# %%
salary_df = salary_df.dropna()

# %%
salary_df
# Out:
#                Player   Age      2025-26
# 0          Trae Young  26.0  $45,999,660
# 1  Kristaps Porziņģis  30.0  $30,731,707
# 2       Jalen Johnson  23.0  $30,000,000
# 3      Onyeka Okongwu  24.0  $15,000,000
# 4  Zaccharie Risacher  20.0  $13,197,720
# 5       Dyson Daniels  22.0   $7,707,709
# 6         Kobe Bufkin  21.0   $4,503,720
# 7          Asa Newell  19.0   $3,237,480
# 8          Vit Krejci  25.0   $2,349,578
# 9      Mouhamed Gueye  22.0   $2,221,677

# %%
combined_df = pd.merge(salary_df, roster_df, on="Player", how="outer").dropna()

# %%
combined_df
# Out:
#                 Player   Age      2025-26  Pos    Ht     Wt  \
# 2        Dyson Daniels  22.0   $7,707,709    G   6-8  199.0
# 5        Jalen Johnson  23.0  $30,000,000    F   6-9  220.0
# 7          Kobe Bufkin  21.0   $4,503,720    G   6-4  195.0
# 8   Kristaps Porziņģis  30.0  $30,731,707  F-C   7-2  240.0
# 10      Mouhamed Gueye  22.0   $2,221,677    F  6-11  210.0
# 14      Onyeka Okongwu  24.0  $15,000,000    F   6-8  235.0
# 15          Trae Young  26.0  $45,999,660    G   6-1  164.0
# 16          Vit Krejci  25.0   $2,349,578    G   6-8  195.0
# 17  Zaccharie Risacher  20.0  $13,197,720    F   6-8  200.0
#
#             Birth Date Birth Exp           College
# 2       March 17, 2003    AU   3     International
# 5    December 18, 2001    US   4              Duke
# 7   September 21, 2003    US   2          Michigan
# 8       August 2, 1995    LV   9     International
# 10    November 9, 2002    SN   2  Washington State
# 14   December 11, 2000    US   5               USC
# 15  September 19, 1998    US   7          Oklahoma
# 16       June 19, 2000    CZ   4     International
# 17       April 8, 2005    ES   1     International

# %%
combined_df = combined_df.sort_values("Player")
combined_df = combined_df.reset_index(drop=True)

# %%
combined_df
# Out:
#                Player   Age      2025-26  Pos    Ht     Wt  \
# 0       Dyson Daniels  22.0   $7,707,709    G   6-8  199.0
# 1       Jalen Johnson  23.0  $30,000,000    F   6-9  220.0
# 2         Kobe Bufkin  21.0   $4,503,720    G   6-4  195.0
# 3  Kristaps Porziņģis  30.0  $30,731,707  F-C   7-2  240.0
# 4      Mouhamed Gueye  22.0   $2,221,677    F  6-11  210.0
# 5      Onyeka Okongwu  24.0  $15,000,000    F   6-8  235.0
# 6          Trae Young  26.0  $45,999,660    G   6-1  164.0
# 7          Vit Krejci  25.0   $2,349,578    G   6-8  195.0
# 8  Zaccharie Risacher  20.0  $13,197,720    F   6-8  200.0
#
#            Birth Date Birth Exp           College
# 0      March 17, 2003    AU   3     International
# 1   December 18, 2001    US   4              Duke
# 2  September 21, 2003    US   2          Michigan
# 3      August 2, 1995    LV   9     International
# 4    November 9, 2002    SN   2  Washington State
# 5   December 11, 2000    US   5               USC
# 6  September 19, 1998    US   7          Oklahoma
# 7       June 19, 2000    CZ   4     International
# 8       April 8, 2005    ES   1     International

# %%
combined_df["PlayerLabel"] = combined_df["Player"].str.replace(" ", "\n", 1)
combined_df["Salary"] = combined_df["2025-26"]
combined_df = combined_df.drop(columns=["2025-26"])

# %%
combined_df.head()
# Out:
#                Player   Age  Pos    Ht     Wt          Birth Date Birth Exp  \
# 0       Dyson Daniels  22.0    G   6-8  199.0      March 17, 2003    AU   3
# 1       Jalen Johnson  23.0    F   6-9  220.0   December 18, 2001    US   4
# 2         Kobe Bufkin  21.0    G   6-4  195.0  September 21, 2003    US   2
# 3  Kristaps Porziņģis  30.0  F-C   7-2  240.0      August 2, 1995    LV   9
# 4      Mouhamed Gueye  22.0    F  6-11  210.0    November 9, 2002    SN   2
#
#             College          PlayerLabel       Salary
# 0     International       Dyson\nDaniels   $7,707,709
# 1              Duke       Jalen\nJohnson  $30,000,000
# 2          Michigan         Kobe\nBufkin   $4,503,720
# 3     International  Kristaps\nPorziņģis  $30,731,707
# 4  Washington State      Mouhamed\nGueye   $2,221,677

# %%
combined_df["Salary_number"] = (combined_df["Salary"].replace(r'[\$,]', '', regex=True).astype('float')) / 1000000

# %%
import seaborn as sns

sns.set(font_scale=0.8)
sns.scatterplot(combined_df, x="PlayerLabel", y="Age")
# Out:
# <Axes: xlabel='PlayerLabel', ylabel='Age'>

# %%
combined_df
# Out:
#                Player   Age  Pos    Ht     Wt          Birth Date Birth Exp  \
# 0       Dyson Daniels  22.0    G   6-8  199.0      March 17, 2003    AU   3
# 1       Jalen Johnson  23.0    F   6-9  220.0   December 18, 2001    US   4
# 2         Kobe Bufkin  21.0    G   6-4  195.0  September 21, 2003    US   2
# 3  Kristaps Porziņģis  30.0  F-C   7-2  240.0      August 2, 1995    LV   9
# 4      Mouhamed Gueye  22.0    F  6-11  210.0    November 9, 2002    SN   2
# 5      Onyeka Okongwu  24.0    F   6-8  235.0   December 11, 2000    US   5
# 6          Trae Young  26.0    G   6-1  164.0  September 19, 1998    US   7
# 7          Vit Krejci  25.0    G   6-8  195.0       June 19, 2000    CZ   4
# 8  Zaccharie Risacher  20.0    F   6-8  200.0       April 8, 2005    ES   1
#
#             College          PlayerLabel       Salary  Salary_number
# 0     International       Dyson\nDaniels   $7,707,709       7.707709
# 1              Duke       Jalen\nJohnson  $30,000,000      30.000000
# 2          Michigan         Kobe\nBufkin   $4,503,720       4.503720
# 3     International  Kristaps\nPorziņģis  $30,731,707      30.731707
# 4  Washington State      Mouhamed\nGueye   $2,221,677       2.221677
# 5               USC      Onyeka\nOkongwu  $15,000,000      15.000000
# 6          Oklahoma          Trae\nYoung  $45,999,660      45.999660
# 7     International          Vit\nKrejci   $2,349,578       2.349578
# 8     International  Zaccharie\nRisacher  $13,197,720      13.197720

# %%
sns.scatterplot(combined_df, x="Age", y="Salary_number")
# Out:
# <Axes: xlabel='Age', ylabel='Salary_number'>

# %%
combined_df.describe()
# Out:
#              Age          Wt  Salary_number
# count   9.000000    9.000000   9.000000e+00
# mean   23.666667  206.444444   1.685686e+07
# std     3.041381   23.179253   1.537998e+07
# min    20.000000  164.000000   2.221677e+06
# 25%    22.000000  195.000000   4.503720e+06
# 50%    23.000000  200.000000   1.319772e+07
# 75%    25.000000  220.000000   3.000000e+07
# max    30.000000  240.000000   4.599966e+07

# %%
url = "https://www.basketball-reference.com/teams/ATL/2026.html"

headers = {"User-Agent": "Mozilla/5.0"}
    html = requests.get(url, headers=headers, timeout=30).text
    soup = BeautifulSoup(html, "html.parser")

    # 1) Try visible table
    t = soup.find("table", id=table_id)
# Out:
# <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt = {cvId: '3',cZone: 'www.basketball-reference.com',cType: 'managed',cRay: '9796fcbc49c14288',cH: 'VRF.OH6M3qRgcKY80SgT99cB56dYr4HBY_A6MwOjWIo-1756920754-1.2.1.1-dGOhTDSVkiYWSkwtyGBRzrrRjAPTE8menEInaPE6i1y9rmYvCrQ5Il89vddD71qf',cUPMDTk:"\/teams\/ATL\/2026.html?__cf_chl_tk=ELlKyDlaYYMki_MklRYvUQcuOgiu2abxIx0CFNH5JkE-1756920754-1.0.1.1-gka9fLefXpcmTuIHlJIaeJtv056Gr_FejQMQRxwrf5M",cFPWv: 'b',cITimeS: '1756920754',cTplC:0,cTplV:5,cTplB: 'cf',fa:"\/teams\/ATL\/2026.html?__cf_chl_f_tk=ELlKyDlaYYMki_MklRYvUQcuOgiu2abxIx0CFNH5JkE-1756920754-1.0.1.1-gka9fLefXpcmTuIHlJIaeJtv056Gr_FejQMQRxwrf5M",md: '1mQPuQvU_VRolbCI_P8IabUqsh5zBr7R7vC5y8Gu8ts-1756920754-1.2.1.1-boYjxLLsopra1l.eUhUeY_lF45MjFCrVIwpJZlak784FdPCr3oqDc6Rs0LeWjwMqhqEnK9h06QNt1nwsPgLIF6Ng2A2JIYniR2hhG3mozeL8FuLiVeqHryUNlZSTHm4_WPbDVaVqPlE3ApAzz86eHZlB9ENTnMJk0PORWZF3pO5qWtfqzHcAid.LNcQMBDKx7VAvDCw5BBq4xUpm6.r7gq8cS2sgXrGqZKKa.5S9pv2k1HJbODSV4IC8UNZKgb62_NaPncKmLhAn2F_7QcpG0oM5CtwMgNGzKY4k5UKwM9vK_Ua7XW__9aXgGOw0WEqVH_CsnRAFY8bZxAGLwIfTzuUgeR.V2RZyEYPxy2CS5bWC0cO4sTeSDR4PL1rqFq4juflzGbGFvhXCJV7fbs7NNRbTQGfbWw4Lvb2BmXJI_0sB3Yoaah0FAy0TfIGyjyLt9oU8rMrg7b9GadKDy5rYBEqNZXY5oaHxtyUJppMvtt6d9.Gji5Ih4G3WQ4uv5ikM7ygtid5siXz9BiLLuMP7JHzkgE7BCt3gckTGbkYPEdD1lP3oIjooxtS3ijZGLUANbecUTsw5M.pJ5A4H7NHenE3hwQ16daxwNzTvegXiNHAsGbuumEP8g1lTuXfmcWrWmQSdBbceY9NGM4NzGUUE2cTzpV4VZvUfxYl3FV9siyaMe.RXUX6vTdxMYtAITgf5Vr4Cql6Dhz0JbN8xj0osFd5XtQk9AHH_Vx08CLIyfxMkrc4dRdr3rPTtrHqEg1ILsXsnmcHoadyXe.svt4kFdoOcqHgSm3q9CetFoxKyIokRbucG414fqkK_nQeOzN9eMBbsQxroME_qZsXLpSpm1XdFCWw0_bMeLXqVAaBmq.tK4ahjvbuWhdHKoFTks0.6_imMKLiSkE2GHwuEuVJJw3yJMyAsDnvYh.w.nxIncAK_anLs7F7zql4rAduKS5QF',mdrd: 'lo2dDroUYz_gFuYJEnYlwyOsVF1sN.osX94IFy5lAig-1756920754-1.2.1.1-W4YAtgNO_gPeDBXhwmIy6aYHnDRZY.mo8NIrl0vL.FCJGxS5Ws0Uj.PZ.KDcwAxNzM74oFdtZqC6V1Ij4UoF8HTqo9_sJr1yIFtTr.PeWthpm5wOLmPdcMJLWGCPTnD4FF8LlIyX55rDcRG9Z1x0JESS.0P7RyscYRfpCnSOFLxNytZwTH58iV4DWrXBdV57vj3maZVvLj7m.6fKmPgjVN0eye6l.VNIVQJKHjoR1GE7IvEoLcDPEm2soLjEwrP5N8pnMKBwY1qPMgcAx24pCA5gHT3HnnlIN.JBIUEX1Ms7CpEUQBqV7m3zqdpxPkOzk.j_9w3QqEDDhQF7B8jqlZwNkzy5TgZLIfIGP.T9rCHsVRwE7uDBqI8Dt_hbH65qeXAAjVFFFcUtp5WWulg.UMUBVbWKeuFRNFEQf7eO_2CWazGE9Hrh6aERymgeK5h7hB8OIslmFqnm8pdA0AFFGhn818SiL8eLviQkxPQLQRymKqw6YgYg43.zRfne8SECSBtbH_8qHSlaWrv8CvL8ySAkVcyDs2SzH28OwSWO0jY9PJ60qNuyDTTZPcY27yNvZS7oB8KV37xm05w4K_RCpQhbrwAjqO4MiV55PxUl_0MNhebbZPXysB2Hyvy4R1pJtUuTB1.xrQfcBtUZNDRAmdxHwNNIE3vOg_qr8q.10he6r0wN.e4FMETPqW0s8jDXBPhLllkpPEWIIelrd_n5vyojqQ3I22n3HO4At5eDp58ljFzU6rDlESs6FPYSHDyq9xKnQWCvvABdySyE2gcMNqXdb5n2ql68yrbj.1XYwCHuL5cqAer11EFsmC_pKRah0gMywFmKjOl_LLG7f.Gy7Y2b ...
# []

# %%
df = pd.read_html(html)[0]
