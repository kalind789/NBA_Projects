# %% [markdown]
# ## NBA GAME PREDICTIONS

# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd

df = pd.read_csv('nba_games.csv', index_col=0)

# %%
df.head()
# Out:
#       mp   mp.1    fg    fga    fg%   3p   3pa    3p%    ft   fta  ...  \
# 0  240.0  240.0  39.0   81.0  0.481  6.0  20.0  0.300  14.0  18.0  ...
# 1  240.0  240.0  36.0  100.0  0.360  7.0  31.0  0.226  16.0  19.0  ...
# 2  240.0  240.0  37.0   85.0  0.435  8.0  19.0  0.421  17.0  23.0  ...
# 3  240.0  240.0  41.0   89.0  0.461  8.0  21.0  0.381  17.0  19.0  ...
# 4  240.0  240.0  27.0   86.0  0.314  6.0  26.0  0.231  15.0  20.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          22.8          29.0         178.0         111.0       DAL
# 1          50.0          32.6         152.0         111.0       ATL
# 2          20.0          30.9         148.0         116.0       SAS
# 3          28.6          30.9         138.0         118.0       MIN
# 4          16.8          30.9         157.0          90.0       MEM
#
#    total_opp  home_opp  season        date    won
# 0         95         1    2016  2015-12-09   True
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)  # without the drop=True the old index gets added as a column to the df
df.head()
# Out:
#       mp   mp.1    fg   fga    fg%   3p   3pa    3p%    ft   fta  ...  \
# 0  240.0  240.0  35.0  83.0  0.422  6.0  18.0  0.333  19.0  27.0  ...
# 1  240.0  240.0  38.0  94.0  0.404  9.0  29.0  0.310  10.0  17.0  ...
# 2  240.0  240.0  37.0  87.0  0.425  7.0  19.0  0.368  16.0  23.0  ...
# 3  240.0  240.0  41.0  96.0  0.427  9.0  30.0  0.300  20.0  22.0  ...
# 4  240.0  240.0  37.0  82.0  0.451  8.0  27.0  0.296  12.0  15.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          69.4          43.7         206.0         104.0       GSW
# 1          53.2          34.6         162.0         104.0       CHI
# 2          30.4          29.0         138.0         105.0       CLE
# 3          37.5          38.9         201.0         120.0       NOP
# 4          33.3          23.6         132.0         104.0       DET
#
#    total_opp  home_opp  season        date    won
# 0        111         1    2016  2015-10-27  False
# ...

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
# The target is the next value in the win column, the result of the NEXT game
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

# Apply the add_target function for a certain team by grouping the df by that team
df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "HOU"]
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 19     240.0  30.0  87.0  0.345   8.0  35.0  0.229  17.0  26.0  0.654  ...
# 40     240.0  30.0  82.0  0.366   5.0  23.0  0.217  27.0  36.0  0.750  ...
# 89     240.0  32.0  79.0  0.405  10.0  36.0  0.278  15.0  18.0  0.833  ...
# 103    240.0  41.0  89.0  0.461   9.0  29.0  0.310  19.0  29.0  0.655  ...
# 135    265.0  42.0  88.0  0.477  11.0  34.0  0.324  24.0  34.0  0.706  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17440  240.0  41.0  97.0  0.423  17.0  45.0  0.378  18.0  26.0  0.692  ...
# 17462  240.0  48.0  85.0  0.565  16.0  40.0  0.400  20.0  29.0  0.690  ...
# 17480  240.0  40.0  99.0  0.404  11.0  43.0  0.256  14.0  25.0  0.560  ...
# 17547  240.0  43.0  81.0  0.531  10.0  29.0  0.345  19.0  24.0  0.792  ...
# 17564  240.0  41.0  89.0  0.461  17.0  46.0  0.370  15.0  20.0  0.750  ...
#
# ...

# %%
# Replace all of the null occurrences of null values in the target column 
df['target'][pd.isnull(df['target'])] = 2

# %%
# Turn the target into a boolean integer value
df['target'] = df['target'].astype(int, errors='ignore')

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
# Check if there is a class imbalance
df["won"].value_counts()
# Out:
# won
# False    8886
# True     8886
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    8872
# 0    8870
# 2      30
# Name: count, dtype: int64

# %%
null_counts = df.isnull().sum()  # Check to see if any columns in the datagrame have a null value. 
null_counts = null_counts[null_counts > 0]
null_counts
# Out:
# +/-             17772
# mp_max          17772
# mp_max.1        17772
# +/-_opp         17772
# mp_max_opp      17772
# mp_max_opp.1    17772
# dtype: int64

# %%
# Since these values are null almost always, we can just get rid of all of them
valid_columns = df.columns[~df.columns.isin(null_counts.index)]

# %%
df.columns, valid_columns
# Out:
# (Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#         ...
#         'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#         'home_opp', 'season', 'date', 'won', 'target'],
#        dtype='object', length=148),
#  Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#         ...
#         'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#         'home_opp', 'season', 'date', 'won', 'target'],
#        dtype='object', length=142))

# %% [markdown]
# We got rid of these values, now the length of the columns in the dataframe decresed from 148 to 142

# %%
df = df[valid_columns].copy()   # Copy allows us to create a new dataframe instead of getting a part of another one.

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# Our current dataframe has a large number of columns. This is a problem because it can create a lot of noise or overfitting and mess with our results. Before going into the machine learning, we will use a feature selector that will allow us to get the important columns.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

# We have time-series data, so we need to make sure that we use a split that accounts for this
rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr,     # The model being used
                                n_features_to_select=30,    # The amount of columns we want left in our data
                                direction="forward",    # This will pick the best feature first and then continue to pick until we have 30
                                cv=split)   #   Time series split used for cross-validation

# %%
# Ridge Regression works best when numbers are normalized within a range, in this case we will normalize the scores between 0 and 1
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]   # These features cant really be turned into numbers, so we will remove them for now

# %%
selected_colums = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_colums] = scaler.fit_transform(df[selected_colums])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# ...

# %%
sfs.fit(df[selected_colums], df['target'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_colums[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'fg%',
#  '3p%',
#  'orb',
#  'ts%',
#  'usg%',
#  '3p%_max',
#  'ft_max',
#  'fta_max',
#  '+/-_max',
#  'drb%_max',
#  'trb%_max',
#  'tov%_max',
#  'usg%_max',
#  'mp_opp',
#  'fg_opp',
#  '3p_opp',
#  'ft%_opp',
#  'blk_opp',
#  'usg%_opp',
#  'fga_max_opp',
#  '3p_max_opp',
#  'ft_max_opp',
#  'ft%_max_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'pts_max_opp',
#  'drb%_max_opp',
#  'blk%_max_opp',
#  'usg%_max_opp']

# %% [markdown]
# These features have been selected as the best to pick by the Feature Selector for Ridge Regression.
#
# The one's with 'max' indicate the player on the team that shot the best.

# %%
def backtest(data, model, predictors, start=2, step=1):
    # Split data by season. Uses past season to predict future seasons. 
    all_predictions = []

    seasons = sorted(data["season"].unique())

    # This loop goes from the third season onwards to the last season
    # The training data is split as all the seasons before, and the test is that season
    for i in range(start, len(seasons), step):
        season = seasons[i]

        train = data[data["season"] < season]
        test = data[data["season"] == season]

        model.fit(train[predictors], train['target'])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)

        combined = pd.concat([test['target'], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        all_predictions.append(combined)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5250        1           1
# 5251        1           1
# 5252        0           0
# 5253        1           0
# 5254        0           1
# ...       ...         ...
# 17767       0           0
# 17768       1           1
# 17769       0           1
# 17770       2           1
# 17771       2           1
#
# [12522 rows x 2 columns]

# %%
# Now let's make a metric to measure the similatirty of these numbers
from sklearn.metrics import accuracy_score

accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5471969333972209

# %%
# Could get a little better score by removing the 2s 
from sklearn.metrics import accuracy_score

sample_predictions = predictions[predictions["actual"] != 2]
accuracy_score(sample_predictions["actual"], sample_predictions["prediction"])
# Out:
# 0.5485110470701249

# %% [markdown]
# ## Improving the Model

# %% [markdown]
# In basketball there are many other nuances that are not accounted for fully in our previous model. The model would have much more accurate predictions if it was given better guidelines to predict on.
#
# For example, we need to have an accuracy that's higher than the % of home teams that win the games or else, we could just use that as our metric instead of doing ML.

# %%
df.groupby("home", group_keys=False).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# /var/folders/jw/63t02ylj29x9q8577qnttn000000gn/T/ipykernel_38580/1197928991.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("home", group_keys=False).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %%
df_rolling = df[list(selected_colums) + ["won", "team", "season"]]

# %%
# We can create a weighted average of how a team performed in their last 10 games, as opposed to just the one game that we are using now
def find_team_averages(team):
    rolling = team[selected_colums].rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# /var/folders/jw/63t02ylj29x9q8577qnttn000000gn/T/ipykernel_38580/2842818123.py:6: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  trb%_max_opp  ast%_max_opp  \
# ...

# %% [markdown]
# Some rows have a lot of missing values due to the fact that the teams have not played 10 games yet.

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  trb%_max_opp_10  ast%_max_opp_10  \
# ...

# %%
# Remove all the null data
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  trb%_max_opp_10  ast%_max_opp_10  \
# ...

# %%
# Give the algortihm a litte more information so that it can make some better judgements
def shift_col(team, col_name):
    # Takes the next rows value and shifts it up to the current row
    next_col =  team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    # Adds the column after the shift into the dataframe to know information about the next game
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] =  add_col(df, "home")

# %%
df["team_opp_next"] =  add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")

# %%
df = df.copy()

# %%
# Pull in stats about the opponents next game as well
# Using an inner join based on the opponent
full = df.merge(
                 df[rolling_cols + ["team_opp_next", "date_next", "team"]],
                 left_on = ["team", "date_next"],
                 right_on = ["team_opp_next", "date_next"]
               )

# %%
# Use sfs on the new dataframe so that we can find the new best features. 
# First we need to remove some of the columns that are not numbers in our dataset. 
removed_columns =  list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_colums = full.columns[~full.columns.isin(removed_columns)]

# %%
# Fit the SFS again:
sfs.fit(full[selected_colums], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_colums[sfs.get_support()])

# %%
predictors
# Out:
# ['3p%',
#  'usg%',
#  'fta_max',
#  'drb_max',
#  'ts%_max',
#  '3p_opp',
#  'trb_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'fg_max_opp',
#  'ft_max_opp',
#  'ft%_max_opp',
#  'pts_10_x',
#  'usg%_10_x',
#  '+/-_max_10_x',
#  'total_10_x',
#  'ft%_opp_10_x',
#  'pf_opp_10_x',
#  'usg%_opp_10_x',
#  'efg%_max_opp_10_x',
#  'drtg_max_opp_10_x',
#  'home_next',
#  'usg%_10_y',
#  'ortg_10_y',
#  '+/-_max_10_y',
#  'ft%_opp_10_y',
#  'usg%_opp_10_y',
#  'fg%_max_opp_10_y',
#  'ast%_max_opp_10_y',
#  'drtg_max_opp_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6316121474272326
